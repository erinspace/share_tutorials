# %% [markdown]
# # SHARE Query Requests from the Community
#
# Here's where we can keep track of code for common things that members of the SHARE community might like to know!
#
# ## Setup

# %%
import json
import requests

SHARE_SEARCH_API = 'https://osf.io/api/v1/share/search/'
ALL_PROVIDER_INFO = requests.get('https://osf.io/api/v1/share/providers/').json()['providerMap']

def query_share(url, query):
    headers = {'Content-Type': 'application/json'}
    data = json.dumps(query)
    return requests.post(url, headers=headers, data=data, verify=False).json()

def get_longname_for_shortname(shortname):
    for source in ALL_PROVIDER_INFO.keys():
        if source == shortname:
            return ALL_PROVIDER_INFO[source]['long_name']

# %% [markdown]
# ## Queries

# %%
# What's the earliest and latest document from each source?

import pandas as pd

date_stats_agg = {
    "aggregations": {
        "sources": {
            "terms": {"field": "_type", "size": 0},
            "aggregations": {
                "source_stats": {
                    "stats": {"field": "providerUpdatedDateTime"}
                }
            }
        }
    }
}

date_results = query_share(SHARE_SEARCH_API, date_stats_agg)['aggregations']['sources']['buckets']

date_results_df = pd.DataFrame()
date_results_df['source_shortname'] = [result['key'].encode('utf-8') for result in date_results]
date_results_df['source_longname'] = [get_longname_for_shortname(name).encode('utf-8') for name in date_results_df['source_shortname']]
date_results_df['earliest_date'] = [result['source_stats']['min_as_string'] for result in date_results]
date_results_df['latest_date'] = [result['source_stats']['max_as_string'] for result in date_results]
date_results_df
# Out:
# /Users/erin/.virtualenvs/tuts/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.py:791: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
#     source_shortname                                    source_longname  \
# 0           datacite                                       DataCite MDS
# 1           crossref                                           CrossRef
# 2           figshare                                           figshare
# 3            scitech                     DoE's SciTech Connect Database
# 4      pubmedcentral                                     PubMed Central
# 5            dataone        DataONE: Data Observation Network for Earth
# 6          arxiv_oai                                              ArXiv
# 7              rcaap  RCAAP - Repositório Científico de Acesso Abert...
# 8          citeseerx  CiteSeerX Scientific Literature Digital Librar...
# 9       cyberleninka  CyberLeninka - Russian open access scientific ...
# 10               bhl       Biodiversity Heritage Library OAI Repository
# 11    clinicaltrials                                 ClinicalTrials.gov
# 12          springer                                           Springer
# 13        uiucideals  University of Illinois at Urbana-Champaign, ID...
# 14               mit                                         DSpace@MIT
# 15              plos                          Public Library of Science
# 16      iowaresearch                               Iowa Research Online
# 17             lshtm  London School of Hygiene and Tropical Medicine...
# 18              krex                          K-State Research Exchange
# 19    ucescholarship            eScholarship @ University of California
# 20     biomedcentral                                     BioMed Central
# 21            zenodo                                             Zenodo
# 22           shareok                                 SHAREOK Repository
# 23          utaustin   University of Texas at Austin Digital Repository
# 24         noaa_nodc                 National Oceanographic Data Center
# 25         cambridge                   Apollo @ University of Cambridge
# 26       uwashington           ResearchWorks @ University of Washington
# 27           caltech                                     CaltechAUTHORS
# 28           ukansas                                    KU ScholarWorks
# 29               asu        Arizona State University Digital Repository
# ..               ...                                                ...
# 85           uhawaii      ScholarSpace at University of Hawaii at Manoa
# 86               udc       University of Minnesota, Digital Conservancy
# 87             elife                                     eLife Sciences
# 88      valposcholar                 Valparaiso University ValpoScholar
# 89          umassmed                                  eScholarship@UMMS
# 90        u_south_fl      University of South Florida - Scholar Commons
# 91        neurovault                                     NeuroVault.org
# 92       spdataverse                          Scholars Portal dataverse
# 93              pcom                                DigitalCommons@PCOM
# 94    ut_chattanooga             University of Tennessee at Chattanooga
# 95               uwo                                 Western University
# 96         colostate                    Digital Collections of Colorado
# 97       triceratops        Triceratops: Tri-College Digital Repository
# 98          utktrace    Trace: Tennessee Research and Creative Exchange
# 99             mason                  Mason Archival Repository Service
# 100      iwu_commons     Digital Commons @ Illinois Wesleyan University
# 101      boise_state                Boise State University ScholarWorks
# 102              fit                    Florida Institute of Technology
# 103          stcloud                   The repository at St Cloud State
# 104             csir                                 CSIR Researchspace
# 105        cogprints                  Cognitive Sciences ePrint Archive
# 106             usgs                    United States Geological Survey
# 107        hacettepe           Hacettepe University DSpace on LibLiveCD
# 108               iu       Indiana University Libraries' IUScholarWorks
# 109            lwbin            Lake Winnipeg Basin Information Network
# 110           purdue       PURR - Purdue University Research Repository
# 111             sldr  Speech and Language Data Repository (SLDR/ORTO...
# 112             ncar                          Earth System Grid at NCAR
# 113             ucsd                                       UC San Diego
# 114             nist                                 NIST MaterialsData
#
#                 earliest_date               latest_date
# 0    2015-07-26T00:03:30.000Z  2016-05-21T01:58:23.000Z
# 1    2014-08-03T00:00:00.000Z  2016-05-22T00:00:00.000Z
# 2    2014-10-28T00:00:00.000Z  2016-05-20T22:13:00.000Z
# 3    2014-10-03T00:00:00.000Z  2016-05-20T00:00:00.000Z
# 4    2014-12-28T00:00:00.000Z  2016-05-20T00:00:00.000Z
# 5    2015-04-11T00:00:00.000Z  2016-05-21T00:00:00.000Z
# 6    2014-10-03T00:00:00.000Z  2016-05-20T00:00:00.000Z
# 7    2015-12-27T02:00:54.000Z  2016-05-22T02:14:38.000Z
# 8    2008-07-01T00:00:00.000Z  2016-05-22T00:00:00.000Z
# 9    2015-12-22T00:00:00.000Z  2016-05-21T23:20:05.000Z
# 10   2015-04-19T19:06:17.000Z  2016-05-21T00:25:49.000Z
# 11   2014-10-07T00:00:00.000Z  2016-05-19T00:00:00.000Z
# 12   2015-11-11T00:00:00.000Z  2016-05-22T00:00:00.000Z
# 13   2015-01-22T19:53:34.000Z  2016-05-20T18:25:15.000Z
# 14   2014-10-04T04:25:20.000Z  2016-05-22T23:41:33.000Z
# 15   2015-04-11T00:00:00.000Z  2016-05-21T00:00:00.000Z
# 16   2011-07-09T12:38:13.000Z  2016-05-20T21:19:31.000Z
# 17   2015-11-17T16:21:22.000Z  2016-05-21T11:36:18.000Z
# 18   2016-01-25T15:24:52.000Z  2016-05-21T07:00:19.000Z
# 19   2013-11-26T00:00:00.000Z  2016-05-21T00:00:00.000Z
# 20   2015-02-04T00:00:00.000Z  2016-05-21T00:00:00.000Z
# 21   2015-04-21T13:07:43.000Z  2016-05-21T08:42:51.000Z
# 22   2015-01-08T02:01:20.000Z  2016-05-21T07:05:27.000Z
# 23   2014-10-24T16:45:59.000Z  2016-05-20T22:41:18.000Z
# 24   2015-09-30T20:18:16.000Z  2016-05-20T18:31:11.000Z
# 25   2015-10-26T10:00:15.000Z  2016-05-20T14:27:16.000Z
# 26   2015-02-04T11:01:48.000Z  2016-05-20T16:26:01.000Z
# 27   2015-04-19T14:25:00.000Z  2016-05-20T23:57:18.000Z
# 28   2016-02-17T09:01:53.000Z  2016-05-20T08:01:28.000Z
# 29   2014-12-01T13:00:31.000Z  2016-05-20T19:48:17.000Z
# ..                        ...                       ...
# 85   2016-04-01T04:05:45.000Z  2016-05-18T00:28:07.000Z
# 86   2016-04-14T14:31:37.000Z  2016-05-18T18:48:46.000Z
# 87   2013-08-06T00:00:00.000Z  2016-01-29T00:00:00.000Z
# 88   2015-01-22T21:35:08.000Z  2016-05-17T20:21:00.000Z
# 89   2016-03-15T19:41:00.000Z  2016-05-19T20:13:59.000Z
# 90   2016-01-25T12:37:20.000Z  2016-05-18T19:16:57.000Z
# 91   2013-07-03T10:48:50.369Z  2015-11-04T16:41:41.220Z
# 92   2014-11-13T18:00:01.000Z  2016-05-18T18:00:01.000Z
# 93   2015-08-31T13:28:12.000Z  2016-05-20T19:11:43.000Z
# 94   2015-01-23T15:27:16.000Z  2016-04-18T13:50:48.000Z
# 95   2016-04-19T16:07:36.000Z  2016-05-21T03:50:54.000Z
# 96   2016-05-16T15:00:40.000Z  2016-05-20T22:00:45.000Z
# 97   2016-05-17T02:00:53.000Z  2016-05-21T02:02:08.000Z
# 98   2015-10-26T21:01:08.000Z  2016-05-12T06:45:37.000Z
# 99   2015-11-16T20:22:33.000Z  2016-05-20T12:46:03.000Z
# 100  2016-01-26T16:47:20.000Z  2016-05-17T03:49:08.000Z
# 101  2016-05-16T16:12:08.000Z  2016-05-20T23:24:52.000Z
# 102  2016-02-22T16:59:19.000Z  2016-05-19T19:59:17.000Z
# 103  2014-12-03T22:38:10.000Z  2016-04-22T01:01:34.000Z
# 104  2016-04-20T21:55:15.000Z  2016-05-16T21:55:26.000Z
# 105  2015-04-20T11:26:30.000Z  2016-03-24T19:13:57.000Z
# 106  2016-02-23T09:24:26.000Z  2016-02-25T10:45:56.000Z
# 107  2014-05-23T23:00:08.000Z  2014-08-26T23:00:09.000Z
# 108  2016-04-19T14:48:25.000Z  2016-05-16T19:22:27.000Z
# 109  2014-11-12T18:04:57.746Z  2015-10-26T13:10:08.862Z
# 110  2015-12-30T05:00:00.000Z  2016-05-17T05:59:24.000Z
# 111  2015-12-15T00:00:00.000Z  2016-04-20T00:00:00.000Z
# 112  2015-10-30T18:28:29.000Z  2016-04-05T17:53:18.000Z
# 113  1961-01-01T00:00:00.000Z  2016-05-19T18:34:30.000Z
# 114  2015-11-02T22:04:55.000Z  2015-11-19T12:30:06.000Z
#
# [115 rows x 4 columns]

# %%
# Uncomment the following lines if running locally - will save to file formats

# date_results_df.to_csv('SHARE_Min_Max_dates.csv')
# date_results_df.to_excel('SHARE_Min_Max_dates.xlsx')

# %% [markdown]
# ## Lucene Search and NOT Queries
#
# A user wanted to know how to query for one term but exclude another

# %%
query = '?q=pedigree NOT child'

# %%
results = requests.get(SHARE_SEARCH_API + query).json()
results
# Out:
# {u'aggregations': None,
#  u'aggs': None,
#  u'count': 1072,
#  u'results': [{u'contributors': [{u'additionalName': u'',
#      u'familyName': u'Tung',
#      u'givenName': u'Jenny',
#      u'name': u'Tung, Jenny'},
#     {u'additionalName': u'B.',
#      u'familyName': u'Barriero',
#      u'givenName': u'Luis',
#      u'name': u'Barriero, Luis B.'},
#     {u'additionalName': u'B.',
#      u'familyName': u'Burns',
#      u'givenName': u'Michael',
#      u'name': u'Burns, Michael B.'},
#     {u'additionalName': u'C.',
#      u'familyName': u'Grenier',
#      u'givenName': u'J.',
#      u'name': u'Grenier, J. C.'},
#     {u'additionalName': u'',
#      u'familyName': u'Lynch',
#      u'givenName': u'Josh',
#      u'name': u'Lynch, Josh'},
#     {u'additionalName': u'E.',
#      u'familyName': u'Grieneisen',
#      u'givenName': u'L.',
#      u'name': u'Grieneisen, L. E.'},
#     {u'additionalName': u'',
#      u'familyName': u'Altmann',
#      u'givenName': u'J.',
#      u'name': u'Altmann, J.'},
#     {u'additionalName': u'C.',
#      u'familyName': u'Alberts',
#      u'givenName': u'S.',
#      u'name': u'Alberts, S. C.'},
#     {u'additionalName': u'',
#      u'familyName': u'Blekhman',
#      u'givenName': u'R.',
#      u'name': u'Blekhman, R.'},
#     {u'additionalName': u'A.',
#      u'familyName': u'Archie',
#      u'givenName': u'E.',
#      u'name': u'Archie, E. A.'}],
#    u'description': u"Pedigree genetic relationships among all 48 subjects in Mica's and Viola's groups",
#    u'highlight': {},
#    u'otherProperties': [{u'name': u'date',
#      u'properties': {u'date': [u'2016-03-19T00:00:00+00:00']}},
#     {u'name': u'identifier',
#      u'properties': {u'identifier': [u'doi:10.5061/DRYAD.8GP03.2/7.2',
#        u'oai:oai.datacite.org:7820416']}},
#     {u'name': u'setSpec', u'properties': {u'setSpec': [u'CDL', u'CDL.DRYAD']}},
#     {u'name': u'description',
#      u'properties': {u'description': [u'Other',
#        u"Pedigree genetic relationships among all 48 subjects in Mica's and Viola's groups"]}}],
#    u'providerUpdatedDateTime': u'2016-03-17T14:50:52+00:00',
#    u'publisher': {u'name': u'Dryad Digital Repository'},
#    u'shareProperties': {u'docID': u'oai:oai.datacite.org:7820416',
#     u'filetype': u'xml',
#     u'source': u'datacite'},
#    u'subjects': [u'social network',
#     u'gut microbiome',
#     u'kenya',
#     u'papio cynocephalus',
#     u'baboon',
#     u'primate',
#     u'sociality',
#     u'grooming',
#     u'amboseli ecosystem'],
#    u'title': u'pedigree',
#    u'uris': {u'canonicalUri': u'http://dx.doi.org/10.5061/DRYAD.8GP03.2/7.2',
#     u'objectUris': [u'http://dx.doi.org/10.5061/DRYAD.8GP03.2/7.2']}},
#   {u'contributors': [{u'additionalName': u'V.',
#      u'familyName': u'Zaragoza',
#      u'givenName': u'Michael',
#      u'name': u'Michael V. Zaragoza'},
#     {u'additionalName': u'',
#      u'familyName': u'Fung',
#      u'givenName': u'Lianna',
#      u'name': u'Lianna Fung'},
#     {u'additionalName': u'',
#      u'familyName': u'Jensen',
#      u'givenName': u'Ember',
#      u'name': u'Ember Jensen'},
#     {u'additionalName': u'',
#      u'familyName': u'Oh',
#      u'givenName': u'Frances',
#      u'name': u'Frances Oh'},
#     {u'additionalName': u'',
#      u'familyName': u'Cung',
#      u'givenName': u'Katherine',
#      u'name': u'Katherine Cung'},
#     {u'additionalName': u'A.',
#      u'familyName': u'McCarthy',
#      u'givenName': u'Linda',
#      u'name': u'Linda A. McCarthy'},
#     {u'additionalName': u'K.',
#      u'familyName': u'Tran',
#      u'givenName': u'Christine',
#      u'name': u'Christine K. Tran'},
#     {u'additionalName': u'',
#      u'familyName': u'',
#      u'givenName': u'Van Hoang',
#      u'name': u'Van Hoang'},
#     {u'additionalName': u'A.',
#      u'familyName': u'Hakim',
#      u'givenName': u'Simin',
#      u'name': u'Simin A. Hakim'},
#     {u'additionalName': u'',
#      u'familyName': u'Grosberg',
#      u'givenName': u'Anna',
#      u'name': u'Anna Grosberg'}],
#    u'description': u'<p>Squares represent males and circles represent females with current age. Short horizontal lines denote individuals consented in the study. Diagonal lines indicate deceased individuals with age of death (d). The proband (III-5) is designated with an arrow. Solid shapes (black) are affected individuals. Unfilled shapes (white) are unaffected individuals defined as those at least 60 years old with no signs/symptoms of cardiac arrhythmia or dysfunction and/or normal cardiac studies. Shapes with a question mark (?) are individuals classified as unknown clinical status. Individual IV-7 died as a neonate; details are not known.</p>',
#    u'highlight': {},
#    u'otherProperties': [{u'name': u'serviceID',
#      u'properties': {u'serviceID': u'3387865'}},
#     {u'name': u'definedType', u'properties': {u'definedType': u'figure'}},
#     {u'name': u'type', u'properties': {u'type': u'figure'}},
#     {u'name': u'publishedDate',
#      u'properties': {u'publishedDate': u'08:25, 16 May, 2016'}}],
#    u'providerUpdatedDateTime': u'2016-05-20T08:33:00+00:00',
#    u'shareProperties': {u'docID': u'3387865',
#     u'filetype': u'json',
#     u'source': u'figshare'},
#    u'title': u'Pedigree.',
#    u'uris': {u'canonicalUri': u'https://dx.doi.org/10.1371/journal.pone.0155421.g001',
#     u'providerUris': [u'https://api.figshare.com/v1/articles/3387865']}},
#   {u'contributors': [{u'additionalName': u'',
#      u'familyName': u'Pigeon',
#      u'givenName': u'Gabriel',
#      u'name': u'Pigeon, Gabriel'},
#     {u'additionalName': u'',
#      u'familyName': u'Festa-Bianchet',
#      u'givenName': u'Marco',
#      u'name': u'Festa-Bianchet, Marco'},
#     {u'additionalName': u'',
#      u'familyName': u'Coltman',
#      u'givenName': u'David',
#      u'name': u'Coltman, David'},
#     {u'additionalName': u'',
#      u'familyName': u'Pelletier',
#      u'givenName': u'Fanie',
#      u'name': u'Pelletier, Fanie'}],
#    u'description': u'Description: Pedigree of the population of bighorn sheep (Ovis canadensis), located at Ram Moutnain, Alberta, Canada(52\xb08\u2019N, 115\xb08\u2019W, elevation 1082 to 2173 m). NA is used for missing values\r\n\r\nColumns: \r\nId: id of the animal\r\ndam: id of the dam\r\nsire: id of the sire',
#    u'highlight': {},
#    u'otherProperties': [{u'name': u'date',
#      u'properties': {u'date': [u'2016-01-09T00:00:00+00:00']}},
#     {u'name': u'identifier',
#      u'properties': {u'identifier': [u'doi:10.5061/DRYAD.41D7Q/2',
#        u'oai:oai.datacite.org:7361137']}},
#     {u'name': u'setSpec', u'properties': {u'setSpec': [u'CDL', u'CDL.DRYAD']}},
#     {u'name': u'description',
#      u'properties': {u'description': [u'Other',
#        u'Description: Pedigree of the population of bighorn sheep (Ovis canadensis), located at Ram Moutnain, Alberta, Canada(52\xb08\u2019N, 115\xb08\u2019W, elevation 1082 to 2173 m). NA is used for missing values\r\n\r\nColumns: \r\nId: id of the animal\r\ndam: id of the dam\r\nsire: id of the sire']}}],
#    u'providerUpdatedDateTime': u'2016-01-07T16:06:53+00:00',
#    u'publisher': {u'name': u'Dryad Digital Repository'},
#    u'shareProperties': {u'docID': u'oai:oai.datacite.org:7361137',
#     u'filetype': u'xml',
#     u'source': u'datacite'},
#    u'subjects': [u'conservation biology',
#     u'quantitative genetics',
#     u'ovis canadensis',
#     u'ram mountain',
#     u'contemporary evolution',
#     u'canada',
#     u'alberta'],
#    u'title': u'pedigree',
#    u'uris': {u'canonicalUri': u'http://dx.doi.org/10.5061/DRYAD.41D7Q/2',
#     u'objectUris': [u'http://dx.doi.org/10.5061/DRYAD.41D7Q/2']}},
#   {u'contributors': [{u'additionalName': u'',
#      u'familyName': u'Ljungstr\xf6m',
#      u'givenName': u'Gabriella',
#      u'name': u'Ljungstr\xf6m, Gabriella'},
#     {u'additionalName': u'',
#      u'familyName': u'Stjernstedt',
#      u'givenName': u'Martin',
#      u'name': u'Stjernstedt, Martin'},
#     {u'additionalName': u'',
#      u'familyName': u'Wapstra',
#      u'givenName': u'Erik',
#      u'name': u'Wapstra, Erik'},
#     {u'additionalName': u'',
#      u'familyName': u'Olsson',
#      u'givenName': u'Mats',
#      u'name': u'Olsson, Mats'}],
#    u'description': u'Made available in DSpace on 2016-02-02T18:58:16Z (GMT). No. of bitstreams: 1\nPedigree.xlsx: 77442 bytes, checksum: ad653647b6a15002c8b3c14f307ee6df (MD5)',
#    u'highlight': {},
#    u'otherProperties': [{u'name': u'date',
#      u'properties': {u'date': [u'2016-02-04T00:00:00+00:00']}},
#     {u'name': u'identifier',
#      u'properties': {u'identifier': [u'doi:10.5061/DRYAD.700JQ/4',
#        u'oai:oai.datacite.org:7571713']}},
#     {u'name': u'setSpec', u'properties': {u'setSpec': [u'CDL', u'CDL.DRYAD']}},
#     {u'name': u'description',
#      u'properties': {u'description': [u'Other',
#        u'Made available in DSpace on 2016-02-02T18:58:16Z (GMT). No. of bitstreams: 1\nPedigree.xlsx: 77442 bytes, checksum: ad653647b6a15002c8b3c14f307ee6df (MD5)']}}],
#    u'providerUpdatedDateTime': u'2016-02-02T18:59:01+00:00',
#    u'publisher': {u'name': u'Dryad Digital Repository'},
#    u'shareProperties': {u'docID': u'oai:oai.datacite.org:7571713',
#     u'filetype': u'xml',
#     u'source': u'datacite'},
#    u'subjects': [u'trade-offs',
#     u'lacerta agilis',
#     u'constraints',
#     u'adaptation',
#     u'natural selection',
#     u'life history evolution',
#     u'amphibians & reptiles'],
#    u'title': u'Pedigree',
#    u'uris': {u'canonicalUri': u'http://dx.doi.org/10.5061/DRYAD.700JQ/4',
#     u'objectUris': [u'http://dx.doi.org/10.5061/DRYAD.700JQ/4']}},
#   {u'contributors': [{u'additionalName': u'',
#      u'email': u'jon.brommer@utu.fi',
#      u'familyName': u'Class',
#      u'givenName': u'Barbara',
#      u'name': u'Class, Barbara'},
#     {u'additionalName': u'E.',
#      u'familyName': u'Brommer',
#      u'givenName': u'Jon',
#      u'name': u'Brommer, Jon E.'}],
#    u'description': u'File contains the pedigree (ID of individual, sire, dam) associated with the datafile',
#    u'freeToRead': {u'startDate': u'2015-06-03'},
#    u'highlight': {},
#    u'otherProperties': [{u'name': u'authorGivenName',
#      u'properties': {u'authorGivenName': [u'Barbara']}},
#     {u'name': u'authorSurName', u'properties': {u'authorSurName': [u'Class']}},
#     {u'name': u'authoritativeMN',
#      u'properties': {u'authoritativeMN': [u'urn:node:DRYAD']}},
#     {u'name': u'checksum',
#      u'properties': {u'checksum': [u'59b3044fd4b433bd27a819448f8be726']}},
#     {u'name': u'checksumAlgorithm',
#      u'properties': {u'checksumAlgorithm': [u'MD5']}},
#     {u'name': u'dataUrl',
#      u'properties': {u'dataUrl': [u'https://cn.dataone.org/cn/v1/resolve/http%3A%2F%2Fdx.doi.org%2F10.5061%2Fdryad.443g2%2F2%3Fver%3D2015-06-03T15%3A22%3A43.874-04%3A00']}},
#     {u'name': u'datasource',
#      u'properties': {u'datasource': [u'urn:node:DRYAD']}},
#     {u'name': u'dateModified',
#      u'properties': {u'dateModified': [u'2015-06-03T19:24:15.86Z']}},
#     {u'name': u'datePublished',
#      u'properties': {u'datePublished': [u'2015-05-12T16:38:52Z']}},
#     {u'name': u'dateUploaded',
#      u'properties': {u'dateUploaded': [u'2015-05-12T16:38:52Z']}},
#     {u'name': u'pubDate',
#      u'properties': {u'pubDate': [u'2015-05-12T16:38:52Z']}},
#     {u'name': u'updateDate',
#      u'properties': {u'updateDate': [u'2015-05-12T16:38:52Z']}},
#     {u'name': u'fileID',
#      u'properties': {u'fileID': [u'https://cn.dataone.org/cn/v1/resolve/http%3A%2F%2Fdx.doi.org%2F10.5061%2Fdryad.443g2%2F2%3Fver%3D2015-06-03T15%3A22%3A43.874-04%3A00']}},
#     {u'name': u'formatId',
#      u'properties': {u'formatId': [u'http://datadryad.org/profile/v3.1']}},
#     {u'name': u'formatType', u'properties': {u'formatType': [u'METADATA']}},
#     {u'name': u'identifier',
#      u'properties': {u'identifier': [u'http://dx.doi.org/10.5061/dryad.443g2/2?ver=2015-06-03T15:22:43.874-04:00']}},
#     {u'name': u'investigator',
#      u'properties': {u'investigator': [u'Class, Barbara',
#        u'Brommer, Jon E.']}},
#     {u'name': u'origin',
#      u'properties': {u'origin': [u'Class, Barbara', u'Brommer, Jon E.']}},
#     {u'name': u'isPublic', u'properties': {u'isPublic': [u'true']}},
#     {u'name': u'readPermission',
#      u'properties': {u'readPermission': [u'public']}},
#     {u'name': u'replicaMN',
#      u'properties': {u'replicaMN': [u'urn:node:DRYAD', u'urn:node:CN']}},
#     {u'name': u'replicaVerifiedDate',
#      u'properties': {u'replicaVerifiedDate': [u'2015-06-03T19:24:14.12Z',
#        u'2015-06-03T19:24:14.25Z']}},
#     {u'name': u'replicationAllowed',
#      u'properties': {u'replicationAllowed': [u'false']}},
#     {u'name': u'numberReplicas', u'properties': {u'numberReplicas': []}},
#     {u'name': u'preferredReplicationMN',
#      u'properties': {u'preferredReplicationMN': []}},
#     {u'name': u'resourceMap',
#      u'properties': {u'resourceMap': [u'http://dx.doi.org/10.5061/dryad.443g2?format=d1rem&ver=2015-06-03T15:22:43.955-04:00']}},
#     {u'name': u'rightsHolder',
#      u'properties': {u'rightsHolder': [u'admin@datadryad.org']}},
#     {u'name': u'scientificName',
#      u'properties': {u'scientificName': [u'Cyanistes cauruleus']}},
#     {u'name': u'site',
#      u'properties': {u'site': [u'60\xb001 N', u'23\xb031 E']}},
#     {u'name': u'size', u'properties': {u'size': [u'1779']}},
#     {u'name': u'sku',
#      u'properties': {u'sku': [u'http://dx.doi.org/10.5061/dryad.443g2/2?ver=2015-06-03T15:22:43.874-04:00']}},
#     {u'name': u'isDocumentedBy',
#      u'properties': {u'isDocumentedBy': [u'http://dx.doi.org/10.5061/dryad.443g2?ver=2015-06-03T15:22:43.955-04:00']}},
#     {u'name': u'serviceID',
#      u'properties': {u'serviceID': [u'http://dx.doi.org/10.5061/dryad.443g2/2?ver=2015-06-03T15:22:43.874-04:00']}}],
#    u'providerUpdatedDateTime': u'2015-06-05',
#    u'shareProperties': {u'docID': u'http://dx.doi.org/10.5061/dryad.443g2/2?ver=2015-06-03T15:22:43.874-04:00',
#     u'source': u'dataone'},
#    u'tags': [u'quantitative genetics',
#     u'personality',
#     u'bird',
#     u'plasticity',
#     u'ontogeny'],
#    u'title': u'pedigree',
#    u'uris': {u'canonicalUri': u'https://cn.dataone.org/cn/v1/resolve/http%3A%2F%2Fdx.doi.org%2F10.5061%2Fdryad.443g2%2F2%3Fver%3D2015-06-03T15%3A22%3A43.874-04%3A00'}},
#   {u'contributors': [{u'additionalName': u'',
#      u'familyName': u'Wapstra',
#      u'givenName': u'Erik',
#      u'name': u'Wapstra, Erik'},
#     {u'additionalName': u'',
#      u'familyName': u'Olsson',
#      u'givenName': u'Mats',
#      u'name': u'Olsson, Mats'},
#     {u'additionalName': u'',
#      u'familyName': u'Stjernstedt',
#      u'givenName': u'Martin',
#      u'name': u'Stjernstedt, Martin'},
#     {u'additionalName': u'',
#      u'email': u'gabriella.ljungstrom@bioenv.gu.se',
#      u'familyName': u'Ljungstr\xf6m',
#      u'givenName': u'Gabriella',
#      u'name': u'Ljungstr\xf6m, Gabriella'}],
#    u'freeToRead': {u'startDate': u'2016-04-18'},
#    u'highlight': {},
#    u'otherProperties': [{u'name': u'authorGivenName',
#      u'properties': {u'authorGivenName': [u'Gabriella']}},
#     {u'name': u'authorSurName',
#      u'properties': {u'authorSurName': [u'Ljungstr\xf6m']}},
#     {u'name': u'authoritativeMN',
#      u'properties': {u'authoritativeMN': [u'urn:node:DRYAD']}},
#     {u'name': u'checksum',
#      u'properties': {u'checksum': [u'433da9930a0953b895228e094820c02b']}},
#     {u'name': u'checksumAlgorithm',
#      u'properties': {u'checksumAlgorithm': [u'MD5']}},
#     {u'name': u'datasource',
#      u'properties': {u'datasource': [u'urn:node:DRYAD']}},
#     {u'name': u'datePublished',
#      u'properties': {u'datePublished': [u'2016-02-02T18:58:16Z']}},
#     {u'name': u'dateUploaded',
#      u'properties': {u'dateUploaded': [u'2016-02-02T18:58:16Z']}},
#     {u'name': u'pubDate',
#      u'properties': {u'pubDate': [u'2016-02-02T18:58:16Z']}},
#     {u'name': u'updateDate',
#      u'properties': {u'updateDate': [u'2016-02-02T18:58:16Z']}},
#     {u'name': u'fileID',
#      u'properties': {u'fileID': [u'https://cn.dataone.org/cn/v2/resolve/http%3A%2F%2Fdx.doi.org%2F10.5061%2Fdryad.700jq%2F4%3Fver%3D2016-04-18T09%3A27%3A49.722-04%3A00']}},
#     {u'name': u'formatId',
#      u'properties': {u'formatId': [u'http://datadryad.org/profile/v3.1']}},
#     {u'name': u'formatType', u'properties': {u'formatType': [u'METADATA']}},
#     {u'name': u'identifier',
#      u'properties': {u'identifier': [u'http://dx.doi.org/10.5061/dryad.700jq/4?ver=2016-04-18T09:27:49.722-04:00']}},
#     {u'name': u'readPermission',
#      u'properties': {u'readPermission': [u'public']}},
#     {u'name': u'replicaMN',
#      u'properties': {u'replicaMN': [u'urn:node:DRYAD', u'urn:node:CN']}},
#     {u'name': u'replicaVerifiedDate',
#      u'properties': {u'replicaVerifiedDate': [u'2016-04-18T13:30:35.68Z',
#        u'2016-04-18T13:30:35.688Z']}},
#     {u'name': u'replicationAllowed',
#      u'properties': {u'replicationAllowed': [u'false']}},
#     {u'name': u'rightsHolder',
#      u'properties': {u'rightsHolder': [u'admin@datadryad.org']}},
#     {u'name': u'scientificName',
#      u'properties': {u'scientificName': [u'Lacerta agilis']}},
#     {u'name': u'size', u'properties': {u'size': [u'1694']}},
#     {u'name': u'isDocumentedBy',
#      u'properties': {u'isDocumentedBy': [u'http://dx.doi.org/10.5061/dryad.700jq?ver=2016-04-18T09:27:47.046-04:00',
#        u'http://dx.doi.org/10.5061/dryad.700jq?ver=2016-04-18T09:39:52.669-04:00',
#        u'http://dx.doi.org/10.5061/dryad.700jq?ver=2016-04-18T09:43:29.237-04:00']}},
#     {u'name': u'serviceID',
#      u'properties': {u'serviceID': [u'http://dx.doi.org/10.5061/dryad.700jq/4?ver=2016-04-18T09:27:49.722-04:00']}}],
#    u'providerUpdatedDateTime': u'2016-04-19T00:00:00+00:00',
#    u'shareProperties': {u'docID': u'http://dx.doi.org/10.5061/dryad.700jq/4?ver=2016-04-18T09:27:49.722-04:00',
#     u'filetype': u'xml',
#     u'source': u'dataone'},
#    u'tags': [u'Life history evolution',
#     u'Trade-offs',
#     u'Amphibians & reptiles',
#     u'Constraints',
#     u'Natural selection',
#     u'Adaptation'],
#    u'title': u'Pedigree',
#    u'uris': {u'canonicalUri': u'http://dx.doi.org/10.5061/dryad.700jq?format=d1rem&ver=2016-04-18T09:43:29.237-04:00',
#     u'objectUris': [u'http://dx.doi.org/10.5061/dryad.700jq/4?ver=2016-04-18T09:27:49.722-04:00',
#      u'https://cn.dataone.org/cn/v2/resolve/http%3A%2F%2Fdx.doi.org%2F10.5061%2Fdryad.700jq%2F4%3Fver%3D2016-04-18T09%3A27%3A49.722-04%3A00',
#      u'http://dx.doi.org/10.5061/dryad.700jq?format=d1rem&ver=2016-04-18T09:27:47.046-04:00',
#      u'http://dx.doi.org/10.5061/dryad.700jq?format=d1rem&ver=2016-04-18T09:39:52.669-04:00',
#      u'http://dx.doi.org/10.5061/dryad.700jq?format=d1rem&ver=2016-04-18T09:43:29.237-04:00'],
#     u'providerUris': []}},
#   {u'contributors': [{u'additionalName': u'C. J.',
#      u'familyName': u'Wientjes',
#      u'givenName': u'Yvonne',
#      u'name': u'Wientjes, Yvonne C. J.'},
#     {u'additionalName': u'',
#      u'familyName': u'Bijma',
#      u'givenName': u'Piter',
#      u'name': u'Bijma, Piter'},
#     {u'additionalName': u'F.',
#      u'familyName': u'Veerkamp',
#      u'givenName': u'Roel',
#      u'name': u'Veerkamp, Roel F.'},
#     {u'additionalName': u'P. L.',
#      u'familyName': u'Calus',
#      u'givenName': u'Mario',
#      u'name': u'Calus, Mario P. L.'}],
#    u'description': u'Pedigree of 1033 animals',
#    u'highlight': {},
#    u'otherProperties': [{u'name': u'date',
#      u'properties': {u'date': [u'2015-12-09T00:00:00+00:00']}},
#     {u'name': u'identifier',
#      u'properties': {u'identifier': [u'doi:10.5061/DRYAD.1525T/2',
#        u'oai:oai.datacite.org:7196752']}},
#     {u'name': u'setSpec', u'properties': {u'setSpec': [u'CDL', u'CDL.DRYAD']}},
#     {u'name': u'description',
#      u'properties': {u'description': [u'Other',
#        u'Pedigree of 1033 animals']}}],
#    u'providerUpdatedDateTime': u'2015-11-30T16:10:07+00:00',
#    u'publisher': {u'name': u'Dryad Digital Repository'},
#    u'shareProperties': {u'docID': u'oai:oai.datacite.org:7196752',
#     u'filetype': u'xml',
#     u'source': u'datacite'},
#    u'subjects': [u'multi-population',
#     u'accuracy',
#     u'genomic prediction',
#     u'prediction equation'],
#    u'title': u'Pedigree',
#    u'uris': {u'canonicalUri': u'http://dx.doi.org/10.5061/DRYAD.1525T/2',
#     u'objectUris': [u'http://dx.doi.org/10.5061/DRYAD.1525T/2']}},
#   {u'contributors': [{u'additionalName': u'E.',
#      u'familyName': u'Grieneisen',
#      u'givenName': u'L.',
#      u'name': u'Grieneisen, L. E.'},
#     {u'additionalName': u'C.',
#      u'familyName': u'Grenier',
#      u'givenName': u'J.',
#      u'name': u'Grenier, J. C.'},
#     {u'additionalName': u'A.',
#      u'familyName': u'Archie',
#      u'givenName': u'E.',
#      u'name': u'Archie, E. A.'},
#     {u'additionalName': u'B.',
#      u'familyName': u'Barriero',
#      u'givenName': u'Luis',
#      u'name': u'Barriero, Luis B.'},
#     {u'additionalName': u'',
#      u'familyName': u'Blekhman',
#      u'givenName': u'R.',
#      u'name': u'Blekhman, R.'},
#     {u'additionalName': u'',
#      u'familyName': u'Altmann',
#      u'givenName': u'J.',
#      u'name': u'Altmann, J.'},
#     {u'additionalName': u'',
#      u'email': u'erin.dryad@gmail.com',
#      u'familyName': u'Tung',
#      u'givenName': u'Jenny',
#      u'name': u'Tung, Jenny'},
#     {u'additionalName': u'',
#      u'familyName': u'Lynch',
#      u'givenName': u'Josh',
#      u'name': u'Lynch, Josh'},
#     {u'additionalName': u'C.',
#      u'familyName': u'Alberts',
#      u'givenName': u'S.',
#      u'name': u'Alberts, S. C.'},
#     {u'additionalName': u'B.',
#      u'familyName': u'Burns',
#      u'givenName': u'Michael',
#      u'name': u'Burns, Michael B.'}],
#    u'description': u"Pedigree genetic relationships among all 48 subjects in Mica's and Viola's groups",
#    u'freeToRead': {u'startDate': u'2016-03-17'},
#    u'highlight': {},
#    u'otherProperties': [{u'name': u'authorGivenName',
#      u'properties': {u'authorGivenName': [u'Jenny']}},
#     {u'name': u'authorSurName', u'properties': {u'authorSurName': [u'Tung']}},
#     {u'name': u'authoritativeMN',
#      u'properties': {u'authoritativeMN': [u'urn:node:DRYAD']}},
#     {u'name': u'checksum',
#      u'properties': {u'checksum': [u'4c5a3db8b870899011f728880707456a']}},
#     {u'name': u'checksumAlgorithm',
#      u'properties': {u'checksumAlgorithm': [u'MD5']}},
#     {u'name': u'datasource',
#      u'properties': {u'datasource': [u'urn:node:DRYAD']}},
#     {u'name': u'datePublished',
#      u'properties': {u'datePublished': [u'2016-03-17T14:48:26Z']}},
#     {u'name': u'dateUploaded',
#      u'properties': {u'dateUploaded': [u'2016-03-17T14:48:26Z']}},
#     {u'name': u'pubDate',
#      u'properties': {u'pubDate': [u'2016-03-17T14:48:26Z']}},
#     {u'name': u'updateDate',
#      u'properties': {u'updateDate': [u'2016-03-17T14:48:26Z']}},
#     {u'name': u'fileID',
#      u'properties': {u'fileID': [u'https://cn.dataone.org/cn/v2/resolve/http%3A%2F%2Fdx.doi.org%2F10.5061%2Fdryad.8gp03.2%2F7.2%3Fver%3D2016-03-17T10%3A50%3A27.970-04%3A00']}},
#     {u'name': u'formatId',
#      u'properties': {u'formatId': [u'http://datadryad.org/profile/v3.1']}},
#     {u'name': u'formatType', u'properties': {u'formatType': [u'METADATA']}},
#     {u'name': u'identifier',
#      u'properties': {u'identifier': [u'http://dx.doi.org/10.5061/dryad.8gp03.2/7.2?ver=2016-03-17T10:50:27.970-04:00']}},
#     {u'name': u'readPermission',
#      u'properties': {u'readPermission': [u'public']}},
#     {u'name': u'replicaMN',
#      u'properties': {u'replicaMN': [u'urn:node:DRYAD', u'urn:node:CN']}},
#     {u'name': u'replicaVerifiedDate',
#      u'properties': {u'replicaVerifiedDate': [u'2016-03-17T14:51:21.425Z',
#        u'2016-03-17T14:51:21.432Z']}},
#     {u'name': u'replicationAllowed',
#      u'properties': {u'replicationAllowed': [u'false']}},
#     {u'name': u'rightsHolder',
#      u'properties': {u'rightsHolder': [u'admin@datadryad.org']}},
#     {u'name': u'scientificName',
#      u'properties': {u'scientificName': [u'Papio cynocephalus']}},
#     {u'name': u'site',
#      u'properties': {u'site': [u'Amboseli ecosystem', u'Kenya']}},
#     {u'name': u'size', u'properties': {u'size': [u'2199']}},
#     {u'name': u'isDocumentedBy',
#      u'properties': {u'isDocumentedBy': [u'http://dx.doi.org/10.5061/dryad.8gp03.2?ver=2016-03-17T10:51:09.595-04:00']}},
#     {u'name': u'serviceID',
#      u'properties': {u'serviceID': [u'http://dx.doi.org/10.5061/dryad.8gp03.2/7.2?ver=2016-03-17T10:50:27.970-04:00']}}],
#    u'providerUpdatedDateTime': u'2016-03-18T00:00:00+00:00',
#    u'shareProperties': {u'docID': u'http://dx.doi.org/10.5061/dryad.8gp03.2/7.2?ver=2016-03-17T10:50:27.970-04:00',
#     u'filetype': u'xml',
#     u'source': u'dataone'},
#    u'tags': [u'Baboon',
#     u'gut microbiome',
#     u'social network',
#     u'sociality',
#     u'grooming',
#     u'primate'],
#    u'title': u'pedigree',
#    u'uris': {u'canonicalUri': u'http://dx.doi.org/10.5061/dryad.8gp03.2?format=d1rem&ver=2016-03-17T10:51:09.595-04:00',
#     u'objectUris': [u'http://dx.doi.org/10.5061/dryad.8gp03.2/7.2?ver=2016-03-17T10:50:27.970-04:00',
#      u'https://cn.dataone.org/cn/v2/resolve/http%3A%2F%2Fdx.doi.org%2F10.5061%2Fdryad.8gp03.2%2F7.2%3Fver%3D2016-03-17T10%3A50%3A27.970-04%3A00',
#      u'http://dx.doi.org/10.5061/dryad.8gp03.2?format=d1rem&ver=2016-03-17T10:51:09.595-04:00'],
#     u'providerUris': []}},
#   {u'contributors': [{u'additionalName': u'Library',
#      u'email': u'',
#      u'familyName': u'U.S. Department of Agriculture',
#      u'givenName': u'Agricultural',
#      u'name': u'U.S. Department of Agriculture, National Agricultural Library',
#      u'sameAs': []},
#     {u'email': u'', u'name': u'D. Landreth Seed Company.', u'sameAs': []},
#     {u'email': u'', u'name': u'Bloomsdale Seed Farms.', u'sameAs': []},
#     {u'email': u'',
#      u'name': u'Henry G. Gilbert Nursery and Seed Trade Catalog Collection.',
#      u'sameAs': []}],
#    u'description': u'1910',
#    u'highlight': {},
#    u'languages': [None],
#    u'providerUpdatedDateTime': u'2015-06-07T00:22:54',
#    u'publisher': {u'name': u'Bristol, Pa. :D. Landreth Seed Company,1910.'},
#    u'shareProperties': {u'docID': u'oai:biodiversitylibrary.org:item/183803',
#     u'source': u'bhl'},
#    u'subjects': [u'plants',
#     u'ornamental',
#     u'catalogs',
#     u'pennsylvania',
#     u'grasses',
#     u'vegetables',
#     u'nursery stock',
#     u'bristol',
#     u'seeds',
#     u'flowers'],
#    u'title': u'Pedigree seeds /',
#    u'uris': {u'canonicalUri': u'http://www.biodiversitylibrary.org/item/183803'}},
#   {u'contributors': [{u'additionalName': u'T.',
#      u'email': u'',
#      u'familyName': u'Wheelwright',
#      u'givenName': u'Nathaniel',
#      u'name': u'Wheelwright, Nathaniel T.',
#      u'sameAs': []},
#     {u'additionalName': u'F.',
#      u'email': u'',
#      u'familyName': u'Keller',
#      u'givenName': u'Lukas',
#      u'name': u'Keller, Lukas F.',
#      u'sameAs': []},
#     {u'additionalName': u'',
#      u'email': u'',
#      u'familyName': u'Postma',
#      u'givenName': u'Erik',
#      u'name': u'Postma, Erik',
#      u'sameAs': []}],
#    u'description': u'Made available in DSpace on 2015-08-19T17:55:16Z (GMT). No. of bitstreams: 1\nSAVS pedigree.txt: 163567 bytes, checksum: 18737f978141a2bc280a65f3efca91fb (MD5)',
#    u'highlight': {},
#    u'languages': [],
#    u'otherProperties': [{u'name': u'date', u'properties': {u'date': u'2015'}},
#     {u'name': u'identifier',
#      u'properties': {u'identifier': [u'doi:10.5061/DRYAD.DV0QT.2/4.2',
#        u'oai:oai.datacite.org:6676124']}},
#     {u'name': u'setSpec', u'properties': {u'setSpec': [u'CDL', u'CDL.DRYAD']}},
#     {u'name': u'description',
#      u'properties': {u'description': [u'Other',
#        u'Made available in DSpace on 2015-08-19T17:55:16Z (GMT). No. of bitstreams: 1\nSAVS pedigree.txt: 163567 bytes, checksum: 18737f978141a2bc280a65f3efca91fb (MD5)']}}],
#    u'providerUpdatedDateTime': u'2015-08-19T17:56:50',
#    u'publisher': {u'name': u'Dryad Digital Repository'},
#    u'shareProperties': {u'docID': u'oai:oai.datacite.org:6676124',
#     u'source': u'datacite'},
#    u'subjects': [u'quantitative genetics',
#     u'genetic variation',
#     u'heritability',
#     u'selection - natural'],
#    u'title': u'SAVS pedigree',
#    u'uris': {u'canonicalUri': u'http://dx.doi.org/10.5061/DRYAD.DV0QT.2/4.2',
#     u'objectUris': [u'http://dx.doi.org/10.5061/DRYAD.DV0QT.2/4.2']}}],
#  u'time': 0.03}

# %% [markdown]
# ## Querying by Document Type
#
# Currently, document type is not curated by SHARE. However, we do collected many sources that are using the OAI-PMH metadata protocol, which includes dc:type. You can search that field in SHARE for now, until the harvesters collect and curate document type.

# %%
query = '?q=otherProperties.properties.type:article'

# %%
results = requests.get(SHARE_SEARCH_API + query).json()

for result in results['results']:
    for prop in result['otherProperties']:
        if prop['name'] == 'type':
            print(prop)
    print(result['title'])
    print(result['uris']['canonicalUri'])
# Out:
# {u'name': u'type', u'properties': {u'type': u'article'}}
# The Phonetics of Register in Takhian Thong Chong
# http://www.escholarship.org/uc/item/1t52p7qb
# {u'name': u'type', u'properties': {u'type': u'article'}}
# Advancing methodological knowledge within state and local demography: a case study.
# http://www.escholarship.org/uc/item/1j85x2qp
# {u'name': u'type', u'properties': {u'type': u'article'}}
# [Front Matter]
# http://www.escholarship.org/uc/item/2fw6515j
# {u'name': u'type', u'properties': {u'type': u'article'}}
# No More "Kicking the Can down the Road"
# http://www.escholarship.org/uc/item/2tj8r6j2
# {u'name': u'type', u'properties': {u'type': u'article'}}
# Finding a Winning Strategy Against the MP3 Invasion: Supplemental Measures the Recording Industry Must Take to Curb Online Piracy
# http://www.escholarship.org/uc/item/61w7d07w
# {u'name': u'type', u'properties': {u'type': u'article'}}
# Proposition 11 - What It Will Do
# http://www.escholarship.org/uc/item/9867d79x
# {u'name': u'type', u'properties': {u'type': u'article'}}
# The Visual Artist and the Law of Defamation
# http://www.escholarship.org/uc/item/1x26m3w2
# {u'name': u'type', u'properties': {u'type': u'article'}}
# Embracing the Burden of Proof: New Strategies for Determining Predictive Links Between Arts Integration Teacher Professional Development, Student Arts Learning, and Student Academic Achievement Outcomes
# http://www.escholarship.org/uc/item/9ch5t8cw
# {u'name': u'type', u'properties': {u'type': u'article'}}
# Epilepsy biomarkers
# http://www.escholarship.org/uc/item/1kx472k3
# {u'name': u'type', u'properties': {u'type': u'article'}}
# Residential and job mobility: Interregional variation and their interplay in US metropolitan areas
# http://www.escholarship.org/uc/item/17q6b7bj

# %% [markdown]
# Here is an analysis of the top terms found in SHARE's collected dc:type field

# %%
import pandas as pd
from sharepa import ShareSearch, basic_search
from sharepa.helpers import pretty_print

type_search = ShareSearch()
total_documents = basic_search.count()

type_search.aggs.bucket(
    'typeTermFilter',  # Every aggregation needs a name
    'terms',  # There are many kinds of aggregations
    field='otherProperties.properties.type',
    exclude= "of|and|or",
    size=50,
)

type_results_executed = type_search.execute()

type_results = type_results_executed.aggregations.typeTermFilter.to_dict()['buckets']

type_dataframe = pd.DataFrame(type_results)
type_dataframe['percent'] = (type_dataframe['doc_count'] / total_documents)*100

# %%
type_dataframe
# Out:
#     doc_count               key    percent
# 0     1807899           article  25.434210
# 1     1507145           journal  21.203088
# 2     1298430              text  18.266807
# 3      232890             paper   3.276385
# 4      207730           dataset   2.922425
# 5      202957              book   2.855276
# 6      197065            figure   2.772385
# 7      133246           info:eu   1.874555
# 8      133246              repo   1.874555
# 9      133246         semantics   1.874555
# 10     123279           chapter   1.734336
# 11     114437            thesis   1.609943
# 12     102018      masterthesis   1.435228
# 13      45107            report   0.634582
# 14      43031  conferenceobject   0.605376
# 15      42916       proceedings   0.603759
# 16      39895         component   0.561258
# 17      39846      peerreviewed   0.560569
# 18      33336        conference   0.468984
# 19      32074      dissertation   0.451229
# 20      30279         technical   0.425976
# 21      24544           fileset   0.345294
# 22      23551             other   0.331324
# 23      19124    journalarticle   0.269044
# 24      19080         reference   0.268425
# 25      19052             entry   0.268031
# 26      17727          research   0.249390
# 27      15753    doctoralthesis   0.221619
# 28      15224              type   0.214177
# 29      15211              http   0.213994
# 30      15210            eprint   0.213980
# 31      15210          purl.org   0.213980
# 32      13700  publishedversion   0.192737
# 33      12351             texto   0.173759
# 34      11541             media   0.162363
# 35      11234          bookpart   0.158044
# 36      10364           version   0.145805
# 37       9053             sound   0.127361
# 38       8922       performance   0.125518
# 39       8451          document   0.118892
# 40       8189             image   0.115206
# 41       7765    bachelorthesis   0.109241
# 42       6381   nonpeerreviewed   0.089770
# 43       6187            survey   0.087041
# 44       5860      presentation   0.082441
# 45       5852             issue   0.082328
# 46       5315            patent   0.074773
# 47       4992          accepted   0.070229
# 48       3837              data   0.053980
# 49       3815           lecture   0.053671

# %% [markdown]
# ## Query by Exact Phrase
#
# Question -- Is there a way to search SHARE for a specific phrase? For example, information literacy, information AND literacy, and "information literacy" give results with both terms, but not necessarily as the phrase "information literacy." Information and literacy can be in different parts of the record.

# %%
phrase_query = {
    "query": {
        "match_phrase" : {
            "title" : "information literacy"
        }
    }
}

results = query_share(SHARE_SEARCH_API, phrase_query)

for result in results['results']:
    print(
        '{} -- from {} -- {}'.format(
            result['title'].encode('utf-8'),
            result['shareProperties']['source'].encode('utf-8'),
            result['uris']['canonicalUri'].encode('utf-8')
        )
    )
# Out:
# Information Literacy -- from uiucideals -- http://hdl.handle.net/2142/41497
# Information Literacy Inventory -- from crossref -- http://dx.doi.org/10.1037/t32581-000
# Information Literacy in Schools -- from crossref -- http://dx.doi.org/10.1201/b19843-8
# Information Literacy Doll -- from datacite -- http://dx.doi.org/10.6084/M9.FIGSHARE.1012828.V1
# MOBILE INFORMATION LITERACY CURRICULUM -- from uwashington -- http://hdl.handle.net/1773/34803
# Information literacy at work -- from crossref -- http://dx.doi.org/10.1108/el-04-2014-0063
# “Real Deal” Information Literacy -- from calpoly -- http://digitalcommons.calpoly.edu/lib_fac/95
# Information Literacy (Book Review) -- from uiucideals -- http://hdl.handle.net/2142/41357
# Teaching Information Literacy Online -- from cuny -- http://academicworks.cuny.edu/ulj/vol18/iss1/5
# Data Information Literacy: Developing Data Information Literacy Programs -- from umassmed -- http://escholarship.umassmed.edu/escience_symposium/2016/program/6
# /Users/erin/.virtualenvs/tuts/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.py:791: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)

# %%
# Using sharepa

phrase_search = ShareSearch()

phrase_search = phrase_search.query(
    'match_phrase',
    title="information literacy"
)

results = phrase_search.execute()

for result in results:
    print(
        '{} -- from {} -- {}'.format(
            result.title.encode('utf-8'),
            result.shareProperties.source.encode('utf-8'),
            result.uris.canonicalUri
        )
    )
# Out:
# Information Literacy -- from uiucideals -- http://hdl.handle.net/2142/41497
# Information Literacy Inventory -- from crossref -- http://dx.doi.org/10.1037/t32581-000
# Information Literacy in Schools -- from crossref -- http://dx.doi.org/10.1201/b19843-8
# Information Literacy Doll -- from datacite -- http://dx.doi.org/10.6084/M9.FIGSHARE.1012828.V1
# MOBILE INFORMATION LITERACY CURRICULUM -- from uwashington -- http://hdl.handle.net/1773/34803
# Information literacy at work -- from crossref -- http://dx.doi.org/10.1108/el-04-2014-0063
# “Real Deal” Information Literacy -- from calpoly -- http://digitalcommons.calpoly.edu/lib_fac/95
# Information Literacy (Book Review) -- from uiucideals -- http://hdl.handle.net/2142/41357
# Teaching Information Literacy Online -- from cuny -- http://academicworks.cuny.edu/ulj/vol18/iss1/5
# Data Information Literacy: Developing Data Information Literacy Programs -- from umassmed -- http://escholarship.umassmed.edu/escience_symposium/2016/program/6
